# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sg

# Q1
aqi_readings = np.random.random(1440)
print(aqi_readings)

# Q3
arr = list()

def averageAQI():
    i = 0
    while(i<1440):
        arr.append(aqi_readings[i:i+60].mean())
        i = i+60
        
    print(arr)
    
averageAQI()

# Q4

X1 = np.linspace(0, 24, 24, endpoint=True)
Y1 = np.array(arr)

plt.plot(X1, Y1, color='blue')

X2 = np.linspace(0, 1440, 1440, endpoint = True)
Y2 = aqi_readings

plt.plot(X2, Y2, color='blue')
# Out:
# [0.1987047  0.04294966 0.34287371 ... 0.55646696 0.03274114 0.1895463 ]
# [0.367182700185087, 0.514857612054748, 0.4916155877883235, 0.508963300401363, 0.48834878136711896, 0.5065981794112863, 0.5856683794337648, 0.47421904683485894, 0.5474824576090921, 0.5398328606396194, 0.4884391103496239, 0.5060947620904803, 0.45814305424264157, 0.5312606253534213, 0.4119845758677489, 0.54473053314365, 0.48275433188560685, 0.47606420288555085, 0.44759486903367096, 0.5590959410078595, 0.49057417743303716, 0.5280630719937527, 0.47036131748042403, 0.4515745685545705]
